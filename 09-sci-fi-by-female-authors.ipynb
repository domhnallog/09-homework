# %% [markdown]
# # Sci-Fi by Female Authors
# > Scrape
# >
# >> Rank
# >>
# >> Title
# >>
# >> Author
# >>
# >> Score
# >>
# >> Votes
# >>
# >> Rating
# >
# > Clean and separate data

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
### TEST VIEWS OF DATA
# print(doc)
# print(doc.prettify())

# %%
### TESTS of Individual Lines
doc.find_all('table')
# group = doc.find_all('table')
# group = doc.find('div', id='all_votes')
# group = doc.find_all(class_='tableList')
# group
# group.find_all('span')
# group.find_all('tr')
# group.find_all('td')
# group.find_all('a')
# group.find_all('a', class_='bookTitle')
# group.find("#all_votes > table > tbody > tr:nth-child(1)")



# #all_votes > table > tbody > tr:nth-child(1) > td:nth-child(3) > a
# Out:
# [<table class="tableList js-dataTooltip">
#  <!-- Add query string params -->
#  <tr itemscope="" itemtype="http://schema.org/Book">
#  <td class="number" valign="top">1</td>
#  <td valign="top" width="5%">
#  <div class="u-anchorTarget" id="38447"></div>
#  <div class="js-tooltipTrigger tooltipTrigger" data-resource-id="38447" data-resource-type="Book">
#  <a href="/book/show/38447.The_Handmaid_s_Tale" title="The Handmaid's Tale">
#  <img alt="The Handmaid's Tale" class="bookCover" itemprop="image" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1546031886i/38447._SY75_.jpg"/>
#  </a> </div>
#  </td>
#  <td valign="top" width="100%">
#  <a class="bookTitle" href="/book/show/38447.The_Handmaid_s_Tale" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">The Handmaid's Tale</span>
#  </a> <br/>
#  <span class="by">by</span>
#  <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#  <div class="authorName__container">
# ...

# %%
site_list = doc.find_all(class_="chart-details")
songs = []
for item in site_list:
    song = {}
    song['rank'] = item.find(class_='chart-list-item__rank').string
#     song['artist'] = item.find(class_='chart-list-item__artist').string
#     song['title'] = item.find(class_='chart-list-item__title-text').string
    songs.append(song)
songs


#main > div.container.chart-container.container--xxlight-grey.container--no-side-padding > div > div:nth-child(1) > div.chart-list-item.now-playing
# Out:
# []

# %%
df = pd.DataFrame(songs)
df.head(25)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
