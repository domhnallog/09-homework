# %% [markdown]
# # Sci-Fi by Female Authors
# > Scrape
# >
# >> Rank
# >>
# >> Title
# >>
# >> Author
# >>
# >> Score
# >>
# >> Votes
# >>
# >> Rating
# >
# > Clean and separate data

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
### TEST VIEWS OF DATA
# print(doc)
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html class="desktop">
#  <head>
#   <title>
#    Science Fiction Books by Female Authors (1385 books)
#   </title>
#   <meta content="1,388 books based on 1395 votes: The Handmaid's Tale by Margaret Atwood, The Hunger Games by Suzanne Collins, Frankenstein by Mary Wollstonecraft Shelley..." name="description"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors" rel="canonical"/>
#   <script type="text/javascript">
#    var ue_t0=window.ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
# ...

# %%
### TESTS of Individual Lines
# test = doc.find_all(class_="container")
test = doc.find_all(class_="chart-details")[0]
# test
# rank = test.find_all(class_='chart-list-item__rank')
artist = test.find_all(class_='chart-list-item__artist')
# title =  test.find(class_='chart-list-item__title-text')
# title =  test.find(class_='chart-list-item__title-text').string
print(rank, artist, title)
# Out:
# [<div class="chart-list-item__rank">
# 1
# </div>, <div class="chart-list-item__rank">
# 2
# </div>, <div class="chart-list-item__rank">
# 3
# </div>, <div class="chart-list-item__rank">
# 4
# </div>, <div class="chart-list-item__rank">
# 5
# </div>, <div class="chart-list-item__rank">
# 6
# </div>, <div class="chart-list-item__rank">
# 7
# </div>, <div class="chart-list-item__rank">
# 8
# </div>, <div class="chart-list-item__rank">
# 9
# </div>, <div class="chart-list-item__rank">
# 10
# </div>, <div class="chart-list-item__rank">
# 11
# </div>, <div class="chart-list-item__rank">
# 12
# </div>, <div class="chart-list-item__rank">
# 13
# </div>, <div class="chart-list-item__rank">
# 14
# </div>, <div class="chart-list-item__rank">
# 15
# </div>, <div class="chart-list-item__rank">
# 16
# </div>, <div class="chart-list-item__rank">
# 17
# </div>, <div class="chart-list-item__rank">
# 18
# </div>, <div class="chart-list-item__rank">
# 19
# </div>, <div class="chart-list-item__rank">
# ...

# %%
site_list = doc.find_all(class_="chart-details")
songs = []
for item in site_list:
    song = {}
    song['rank'] = item.find(class_='chart-list-item__rank').string
#     song['artist'] = item.find(class_='chart-list-item__artist').string
#     song['title'] = item.find(class_='chart-list-item__title-text').string
    songs.append(song)
songs


#main > div.container.chart-container.container--xxlight-grey.container--no-side-padding > div > div:nth-child(1) > div.chart-list-item.now-playing
# Out:
# [{'rank': '\n1\n'}]

# %%
df = pd.DataFrame(songs)
df.head(25)
# Out:
#                                               artist  \
# 0  <div class="chart-list-item__artist">
# Lil Nas ...
#
#                                            rank  \
# 0  <div class="chart-list-item__rank">
# 1
# </div>
#
#                                                title
# 0  <span class="chart-list-item__title-text">
# Old...
